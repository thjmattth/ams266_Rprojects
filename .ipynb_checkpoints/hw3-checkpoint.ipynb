# %% [markdown]
# Before you turn this problem set in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel$\rightarrow$Restart) and then **run all cells** (in the menubar, select Cell$\rightarrow$Run All). Note that in code sections, you must replace `stop("Not Implemented")` with your code. Otherwise, you will have points automatically deducted in the grading process.
#
# **Please do not rename this file.**
#
# Make sure you fill in any place that says `YOUR CODE HERE` or "YOUR ANSWER/EXPLANATION HERE", as well as your name below:

# %%
NAME = "Thomas J Matthew"

# %% [markdown]
# ---

# %% [markdown]
# # Problem  1
#
# As has been previously discussed, there are many classes for objects in R. One such class is the `Date` class. Write a simple function called `days_old` that calculates how many days old someone is based on their birthday, given as a `Date`-class object. This code should work on any date someone tries to run it, and make sure that the result is a numeric-class object.
#
# Hint: Check out the function `Sys.Date`.

# %%
days_old <- function(x){
   return (as.numeric(difftime(Sys.Date(), x, units="days")))

}

# %% [markdown]
# The following test will see if your function works correctly. Make sure to test your code on something that you know the age of, in days.

# %%
stopifnot(is.numeric(days_old(as.Date("2010-07-17"))))

# %% [markdown]
# ---
#
# # Problem 2
#
# Let's imagine that there are no `sum` or `mean` functions in R. Write a function to find the mean (average) of a vector of numbers without using either of those functions.

# %%
my_mean <- function(x = c(2,4,6)){
    runsum = 0
    for (i in x){
        runsum = runsum + i 
    }
    return(runsum/length(x))   
}
my_mean()
# Out:
# [1] 4

# %% [markdown]
# Let's test that your function works.

# %%
stopifnot(my_mean(c(1:9)) == mean(c(1:9)))

# %% [markdown]
# ---
#
# # Problem 3
#
# Using the `iris` data set in R, write a function using a `for` loop and separate `if` and `else` statements to output a character vector of length 150 such that each element is either a string that reads "Sepal width is less than 3!" or "Sepal width is greater than or equal to 3!", based on the `Sepal.Width` variable. The input for your function should be `iris$Sepal.Width`.

# %%
data("iris")
sepal_width_group_for <- function(x = iris$Sepal.Width){
    vector <- character()
    for (i in x){
        if (i < 3){
            line <- 'Sepal width is less than 3!'
        }
        else{
            line <- 'Sepal width is greater than or equal to 3!'
        }
        vector <- append(vector, line)
    }
    return(vector)
}

# %%
#testing above
length(sepal_width_group_for())
sepal_width_group_for()
# Out:
# [1] 150
#   [1] "Sepal width is greater than or equal to 3!"
#   [2] "Sepal width is greater than or equal to 3!"
#   [3] "Sepal width is greater than or equal to 3!"
#   [4] "Sepal width is greater than or equal to 3!"
#   [5] "Sepal width is greater than or equal to 3!"
#   [6] "Sepal width is greater than or equal to 3!"
#   [7] "Sepal width is greater than or equal to 3!"
#   [8] "Sepal width is greater than or equal to 3!"
#   [9] "Sepal width is less than 3!"
#  [10] "Sepal width is greater than or equal to 3!"
#  [11] "Sepal width is greater than or equal to 3!"
#  [12] "Sepal width is greater than or equal to 3!"
#  [13] "Sepal width is greater than or equal to 3!"
#  [14] "Sepal width is greater than or equal to 3!"
#  [15] "Sepal width is greater than or equal to 3!"
#  [16] "Sepal width is greater than or equal to 3!"
#  [17] "Sepal width is greater than or equal to 3!"
#  [18] "Sepal width is greater than or equal to 3!"
#  [19] "Sepal width is greater than or equal to 3!"
#  [20] "Sepal width is greater than or equal to 3!"
#  [21] "Sepal width is greater than or equal to 3!"
#  [22] "Sepal width is greater than or equal to 3!"
#  [23] "Sepal width is greater than or equal to 3!"
#  [24] "Sepal width is greater than or equal to 3!"
#  [25] "Sepal width is greater than or equal to 3!"
#  [26] "Sepal width is greater than or equal to 3!"
#  [27] "Sepal width is greater than or equal to 3!"
#  [28] "Sepal width is greater than or equal to 3!"
#  [29] "Sepal width is greater than or equal to 3!"
#  [30] "Sepal width is greater than or equal to 3!"
#  [31] "Sepal width is greater than or equal to 3!"
#  [32] "Sepal width is greater than or equal to 3!"
#  [33] "Sepal width is greater than or equal to 3!"
#  [34] "Sepal width is greater than or equal to 3!"
#  [35] "Sepal width is greater than or equal to 3!"
#  [36] "Sepal width is greater than or equal to 3!"
#  [37] "Sepal width is greater than or equal to 3!"
#  [38] "Sepal width is greater than or equal to 3!"
#  [39] "Sepal width is greater than or equal to 3!"
#  [40] "Sepal width is greater than or equal to 3!"
#  [41] "Sepal width is greater than or equal to 3!"
#  [42] "Sepal width is less than 3!"
#  [43] "Sepal width is greater than or equal to 3!"
#  [44] "Sepal width is greater than or equal to 3!"
#  [45] "Sepal width is greater than or equal to 3!"
#  [46] "Sepal width is greater than or equal to 3!"
#  [47] "Sepal width is greater than or equal to 3!"
#  [48] "Sepal width is greater than or equal to 3!"
#  [49] "Sepal width is greater than or equal to 3!"
#  [50] "Sepal width is greater than or equal to 3!"
#  [51] "Sepal width is greater than or equal to 3!"
#  [52] "Sepal width is greater than or equal to 3!"
#  [53] "Sepal width is greater than or equal to 3!"
#  [54] "Sepal width is less than 3!"
#  [55] "Sepal width is less than 3!"
#  [56] "Sepal width is less than 3!"
#  [57] "Sepal width is greater than or equal to 3!"
#  [58] "Sepal width is less than 3!"
#  [59] "Sepal width is less than 3!"
#  [60] "Sepal width is less than 3!"
#  [61] "Sepal width is less than 3!"
#  [62] "Sepal width is greater than or equal to 3!"
#  [63] "Sepal width is less than 3!"
#  [64] "Sepal width is less than 3!"
#  [65] "Sepal width is less than 3!"
#  [66] "Sepal width is greater than or equal to 3!"
#  [67] "Sepal width is greater than or equal to 3!"
#  [68] "Sepal width is less than 3!"
#  [69] "Sepal width is less than 3!"
#  [70] "Sepal width is less than 3!"
#  [71] "Sepal width is greater than or equal to 3!"
#  [72] "Sepal width is less than 3!"
#  [73] "Sepal width is less than 3!"
#  [74] "Sepal width is less than 3!"
#  [75] "Sepal width is less than 3!"
#  [76] "Sepal width is greater than or equal to 3!"
#  [77] "Sepal width is less than 3!"
#  [78] "Sepal width is greater than or equal to 3!"
#  [79] "Sepal width is less than 3!"
#  [80] "Sepal width is less than 3!"
#  [81] "Sepal width is less than 3!"
#  [82] "Sepal width is less than 3!"
#  [83] "Sepal width is less than 3!"
#  [84] "Sepal width is less than 3!"
#  [85] "Sepal width is greater than or equal to 3!"
#  [86] "Sepal width is greater than or equal to 3!"
#  [87] "Sepal width is greater than or equal to 3!"
#  [88] "Sepal width is less than 3!"
#  [89] "Sepal width is greater than or equal to 3!"
#  [90] "Sepal width is less than 3!"
#  [91] "Sepal width is less than 3!"
#  [92] "Sepal width is greater than or equal to 3!"
#  [93] "Sepal width is less than 3!"
#  [94] "Sepal width is less than 3!"
#  [95] "Sepal width is less than 3!"
#  [96] "Sepal width is greater than or equal to 3!"
#  [97] "Sepal width is less than 3!"
#  [98] "Sepal width is less than 3!"
#  [99] "Sepal width is less than 3!"
# [100] "Sepal width is less than 3!"
# [101] "Sepal width is greater than or equal to 3!"
# [102] "Sepal width is less than 3!"
# [103] "Sepal width is greater than or equal to 3!"
# [104] "Sepal width is less than 3!"
# [105] "Sepal width is greater than or equal to 3!"
# [106] "Sepal width is greater than or equal to 3!"
# [107] "Sepal width is less than 3!"
# [108] "Sepal width is less than 3!"
# [109] "Sepal width is less than 3!"
# [110] "Sepal width is greater than or equal to 3!"
# [111] "Sepal width is greater than or equal to 3!"
# [112] "Sepal width is less than 3!"
# [113] "Sepal width is greater than or equal to 3!"
# [114] "Sepal width is less than 3!"
# [115] "Sepal width is less than 3!"
# [116] "Sepal width is greater than or equal to 3!"
# [117] "Sepal width is greater than or equal to 3!"
# [118] "Sepal width is greater than or equal to 3!"
# [119] "Sepal width is less than 3!"
# [120] "Sepal width is less than 3!"
# [121] "Sepal width is greater than or equal to 3!"
# [122] "Sepal width is less than 3!"
# [123] "Sepal width is less than 3!"
# [124] "Sepal width is less than 3!"
# [125] "Sepal width is greater than or equal to 3!"
# [126] "Sepal width is greater than or equal to 3!"
# [127] "Sepal width is less than 3!"
# [128] "Sepal width is greater than or equal to 3!"
# [129] "Sepal width is less than 3!"
# [130] "Sepal width is greater than or equal to 3!"
# [131] "Sepal width is less than 3!"
# [132] "Sepal width is greater than or equal to 3!"
# [133] "Sepal width is less than 3!"
# [134] "Sepal width is less than 3!"
# [135] "Sepal width is less than 3!"
# [136] "Sepal width is greater than or equal to 3!"
# [137] "Sepal width is greater than or equal to 3!"
# [138] "Sepal width is greater than or equal to 3!"
# [139] "Sepal width is greater than or equal to 3!"
# [140] "Sepal width is greater than or equal to 3!"
# [141] "Sepal width is greater than or equal to 3!"
# [142] "Sepal width is greater than or equal to 3!"
# [143] "Sepal width is less than 3!"
# [144] "Sepal width is greater than or equal to 3!"
# [145] "Sepal width is greater than or equal to 3!"
# [146] "Sepal width is greater than or equal to 3!"
# [147] "Sepal width is less than 3!"
# [148] "Sepal width is greater than or equal to 3!"
# [149] "Sepal width is greater than or equal to 3!"
# [150] "Sepal width is greater than or equal to 3!"

# %% [markdown]
# Next, do the same thing using the `ifelse` function.

# %%
sepal_width_group_ifelse <- function(x = iris$Sepal.Width){
    return(ifelse(x < 3, 'Sepal width is less than 3!', 
                  'Sepal width is greater than or equal to 3!'))
}

# %%
#testing above
length(sepal_width_group_ifelse())
sepal_width_group_ifelse()
# Out:
# [1] 150
#   [1] "Sepal width is greater than or equal to 3!"
#   [2] "Sepal width is greater than or equal to 3!"
#   [3] "Sepal width is greater than or equal to 3!"
#   [4] "Sepal width is greater than or equal to 3!"
#   [5] "Sepal width is greater than or equal to 3!"
#   [6] "Sepal width is greater than or equal to 3!"
#   [7] "Sepal width is greater than or equal to 3!"
#   [8] "Sepal width is greater than or equal to 3!"
#   [9] "Sepal width is less than 3!"
#  [10] "Sepal width is greater than or equal to 3!"
#  [11] "Sepal width is greater than or equal to 3!"
#  [12] "Sepal width is greater than or equal to 3!"
#  [13] "Sepal width is greater than or equal to 3!"
#  [14] "Sepal width is greater than or equal to 3!"
#  [15] "Sepal width is greater than or equal to 3!"
#  [16] "Sepal width is greater than or equal to 3!"
#  [17] "Sepal width is greater than or equal to 3!"
#  [18] "Sepal width is greater than or equal to 3!"
#  [19] "Sepal width is greater than or equal to 3!"
#  [20] "Sepal width is greater than or equal to 3!"
#  [21] "Sepal width is greater than or equal to 3!"
#  [22] "Sepal width is greater than or equal to 3!"
#  [23] "Sepal width is greater than or equal to 3!"
#  [24] "Sepal width is greater than or equal to 3!"
#  [25] "Sepal width is greater than or equal to 3!"
#  [26] "Sepal width is greater than or equal to 3!"
#  [27] "Sepal width is greater than or equal to 3!"
#  [28] "Sepal width is greater than or equal to 3!"
#  [29] "Sepal width is greater than or equal to 3!"
#  [30] "Sepal width is greater than or equal to 3!"
#  [31] "Sepal width is greater than or equal to 3!"
#  [32] "Sepal width is greater than or equal to 3!"
#  [33] "Sepal width is greater than or equal to 3!"
#  [34] "Sepal width is greater than or equal to 3!"
#  [35] "Sepal width is greater than or equal to 3!"
#  [36] "Sepal width is greater than or equal to 3!"
#  [37] "Sepal width is greater than or equal to 3!"
#  [38] "Sepal width is greater than or equal to 3!"
#  [39] "Sepal width is greater than or equal to 3!"
#  [40] "Sepal width is greater than or equal to 3!"
#  [41] "Sepal width is greater than or equal to 3!"
#  [42] "Sepal width is less than 3!"
#  [43] "Sepal width is greater than or equal to 3!"
#  [44] "Sepal width is greater than or equal to 3!"
#  [45] "Sepal width is greater than or equal to 3!"
#  [46] "Sepal width is greater than or equal to 3!"
#  [47] "Sepal width is greater than or equal to 3!"
#  [48] "Sepal width is greater than or equal to 3!"
#  [49] "Sepal width is greater than or equal to 3!"
#  [50] "Sepal width is greater than or equal to 3!"
#  [51] "Sepal width is greater than or equal to 3!"
#  [52] "Sepal width is greater than or equal to 3!"
#  [53] "Sepal width is greater than or equal to 3!"
#  [54] "Sepal width is less than 3!"
#  [55] "Sepal width is less than 3!"
#  [56] "Sepal width is less than 3!"
#  [57] "Sepal width is greater than or equal to 3!"
#  [58] "Sepal width is less than 3!"
#  [59] "Sepal width is less than 3!"
#  [60] "Sepal width is less than 3!"
#  [61] "Sepal width is less than 3!"
#  [62] "Sepal width is greater than or equal to 3!"
#  [63] "Sepal width is less than 3!"
#  [64] "Sepal width is less than 3!"
#  [65] "Sepal width is less than 3!"
#  [66] "Sepal width is greater than or equal to 3!"
#  [67] "Sepal width is greater than or equal to 3!"
#  [68] "Sepal width is less than 3!"
#  [69] "Sepal width is less than 3!"
#  [70] "Sepal width is less than 3!"
#  [71] "Sepal width is greater than or equal to 3!"
#  [72] "Sepal width is less than 3!"
#  [73] "Sepal width is less than 3!"
#  [74] "Sepal width is less than 3!"
#  [75] "Sepal width is less than 3!"
#  [76] "Sepal width is greater than or equal to 3!"
#  [77] "Sepal width is less than 3!"
#  [78] "Sepal width is greater than or equal to 3!"
#  [79] "Sepal width is less than 3!"
#  [80] "Sepal width is less than 3!"
#  [81] "Sepal width is less than 3!"
#  [82] "Sepal width is less than 3!"
#  [83] "Sepal width is less than 3!"
#  [84] "Sepal width is less than 3!"
#  [85] "Sepal width is greater than or equal to 3!"
#  [86] "Sepal width is greater than or equal to 3!"
#  [87] "Sepal width is greater than or equal to 3!"
#  [88] "Sepal width is less than 3!"
#  [89] "Sepal width is greater than or equal to 3!"
#  [90] "Sepal width is less than 3!"
#  [91] "Sepal width is less than 3!"
#  [92] "Sepal width is greater than or equal to 3!"
#  [93] "Sepal width is less than 3!"
#  [94] "Sepal width is less than 3!"
#  [95] "Sepal width is less than 3!"
#  [96] "Sepal width is greater than or equal to 3!"
#  [97] "Sepal width is less than 3!"
#  [98] "Sepal width is less than 3!"
#  [99] "Sepal width is less than 3!"
# [100] "Sepal width is less than 3!"
# [101] "Sepal width is greater than or equal to 3!"
# [102] "Sepal width is less than 3!"
# [103] "Sepal width is greater than or equal to 3!"
# [104] "Sepal width is less than 3!"
# [105] "Sepal width is greater than or equal to 3!"
# [106] "Sepal width is greater than or equal to 3!"
# [107] "Sepal width is less than 3!"
# [108] "Sepal width is less than 3!"
# [109] "Sepal width is less than 3!"
# [110] "Sepal width is greater than or equal to 3!"
# [111] "Sepal width is greater than or equal to 3!"
# [112] "Sepal width is less than 3!"
# [113] "Sepal width is greater than or equal to 3!"
# [114] "Sepal width is less than 3!"
# [115] "Sepal width is less than 3!"
# [116] "Sepal width is greater than or equal to 3!"
# [117] "Sepal width is greater than or equal to 3!"
# [118] "Sepal width is greater than or equal to 3!"
# [119] "Sepal width is less than 3!"
# [120] "Sepal width is less than 3!"
# [121] "Sepal width is greater than or equal to 3!"
# [122] "Sepal width is less than 3!"
# [123] "Sepal width is less than 3!"
# [124] "Sepal width is less than 3!"
# [125] "Sepal width is greater than or equal to 3!"
# [126] "Sepal width is greater than or equal to 3!"
# [127] "Sepal width is less than 3!"
# [128] "Sepal width is greater than or equal to 3!"
# [129] "Sepal width is less than 3!"
# [130] "Sepal width is greater than or equal to 3!"
# [131] "Sepal width is less than 3!"
# [132] "Sepal width is greater than or equal to 3!"
# [133] "Sepal width is less than 3!"
# [134] "Sepal width is less than 3!"
# [135] "Sepal width is less than 3!"
# [136] "Sepal width is greater than or equal to 3!"
# [137] "Sepal width is greater than or equal to 3!"
# [138] "Sepal width is greater than or equal to 3!"
# [139] "Sepal width is greater than or equal to 3!"
# [140] "Sepal width is greater than or equal to 3!"
# [141] "Sepal width is greater than or equal to 3!"
# [142] "Sepal width is greater than or equal to 3!"
# [143] "Sepal width is less than 3!"
# [144] "Sepal width is greater than or equal to 3!"
# [145] "Sepal width is greater than or equal to 3!"
# [146] "Sepal width is greater than or equal to 3!"
# [147] "Sepal width is less than 3!"
# [148] "Sepal width is greater than or equal to 3!"
# [149] "Sepal width is greater than or equal to 3!"
# [150] "Sepal width is greater than or equal to 3!"

# %% [markdown]
# Finally, do the same thing using the `sapply` function with the `sepal_width_group_ifelse` function. Note that you will not be able to use the `sapply` function if your input is `iris$Sepal.Width`. See the help page for details on how the `sapply` function works.

# %%
sepal_width_group_apply <- function(x = iris$Sepal.Width){
    x <- as.matrix(x)
    return(apply(x, 1, function(x) {ifelse(x < 3, 'Sepal width is less than 3!', 
                  'Sepal width is greater than or equal to 3!')}))
}

# %%
#testing above
length(sepal_width_group_apply())
sepal_width_group_apply()
# Out:
# [1] 150
#   [1] "Sepal width is greater than or equal to 3!"
#   [2] "Sepal width is greater than or equal to 3!"
#   [3] "Sepal width is greater than or equal to 3!"
#   [4] "Sepal width is greater than or equal to 3!"
#   [5] "Sepal width is greater than or equal to 3!"
#   [6] "Sepal width is greater than or equal to 3!"
#   [7] "Sepal width is greater than or equal to 3!"
#   [8] "Sepal width is greater than or equal to 3!"
#   [9] "Sepal width is less than 3!"
#  [10] "Sepal width is greater than or equal to 3!"
#  [11] "Sepal width is greater than or equal to 3!"
#  [12] "Sepal width is greater than or equal to 3!"
#  [13] "Sepal width is greater than or equal to 3!"
#  [14] "Sepal width is greater than or equal to 3!"
#  [15] "Sepal width is greater than or equal to 3!"
#  [16] "Sepal width is greater than or equal to 3!"
#  [17] "Sepal width is greater than or equal to 3!"
#  [18] "Sepal width is greater than or equal to 3!"
#  [19] "Sepal width is greater than or equal to 3!"
#  [20] "Sepal width is greater than or equal to 3!"
#  [21] "Sepal width is greater than or equal to 3!"
#  [22] "Sepal width is greater than or equal to 3!"
#  [23] "Sepal width is greater than or equal to 3!"
#  [24] "Sepal width is greater than or equal to 3!"
#  [25] "Sepal width is greater than or equal to 3!"
#  [26] "Sepal width is greater than or equal to 3!"
#  [27] "Sepal width is greater than or equal to 3!"
#  [28] "Sepal width is greater than or equal to 3!"
#  [29] "Sepal width is greater than or equal to 3!"
#  [30] "Sepal width is greater than or equal to 3!"
#  [31] "Sepal width is greater than or equal to 3!"
#  [32] "Sepal width is greater than or equal to 3!"
#  [33] "Sepal width is greater than or equal to 3!"
#  [34] "Sepal width is greater than or equal to 3!"
#  [35] "Sepal width is greater than or equal to 3!"
#  [36] "Sepal width is greater than or equal to 3!"
#  [37] "Sepal width is greater than or equal to 3!"
#  [38] "Sepal width is greater than or equal to 3!"
#  [39] "Sepal width is greater than or equal to 3!"
#  [40] "Sepal width is greater than or equal to 3!"
#  [41] "Sepal width is greater than or equal to 3!"
#  [42] "Sepal width is less than 3!"
#  [43] "Sepal width is greater than or equal to 3!"
#  [44] "Sepal width is greater than or equal to 3!"
#  [45] "Sepal width is greater than or equal to 3!"
#  [46] "Sepal width is greater than or equal to 3!"
#  [47] "Sepal width is greater than or equal to 3!"
#  [48] "Sepal width is greater than or equal to 3!"
#  [49] "Sepal width is greater than or equal to 3!"
#  [50] "Sepal width is greater than or equal to 3!"
#  [51] "Sepal width is greater than or equal to 3!"
#  [52] "Sepal width is greater than or equal to 3!"
#  [53] "Sepal width is greater than or equal to 3!"
#  [54] "Sepal width is less than 3!"
#  [55] "Sepal width is less than 3!"
#  [56] "Sepal width is less than 3!"
#  [57] "Sepal width is greater than or equal to 3!"
#  [58] "Sepal width is less than 3!"
#  [59] "Sepal width is less than 3!"
#  [60] "Sepal width is less than 3!"
#  [61] "Sepal width is less than 3!"
#  [62] "Sepal width is greater than or equal to 3!"
#  [63] "Sepal width is less than 3!"
#  [64] "Sepal width is less than 3!"
#  [65] "Sepal width is less than 3!"
#  [66] "Sepal width is greater than or equal to 3!"
#  [67] "Sepal width is greater than or equal to 3!"
#  [68] "Sepal width is less than 3!"
#  [69] "Sepal width is less than 3!"
#  [70] "Sepal width is less than 3!"
#  [71] "Sepal width is greater than or equal to 3!"
#  [72] "Sepal width is less than 3!"
#  [73] "Sepal width is less than 3!"
#  [74] "Sepal width is less than 3!"
#  [75] "Sepal width is less than 3!"
#  [76] "Sepal width is greater than or equal to 3!"
#  [77] "Sepal width is less than 3!"
#  [78] "Sepal width is greater than or equal to 3!"
#  [79] "Sepal width is less than 3!"
#  [80] "Sepal width is less than 3!"
#  [81] "Sepal width is less than 3!"
#  [82] "Sepal width is less than 3!"
#  [83] "Sepal width is less than 3!"
#  [84] "Sepal width is less than 3!"
#  [85] "Sepal width is greater than or equal to 3!"
#  [86] "Sepal width is greater than or equal to 3!"
#  [87] "Sepal width is greater than or equal to 3!"
#  [88] "Sepal width is less than 3!"
#  [89] "Sepal width is greater than or equal to 3!"
#  [90] "Sepal width is less than 3!"
#  [91] "Sepal width is less than 3!"
#  [92] "Sepal width is greater than or equal to 3!"
#  [93] "Sepal width is less than 3!"
#  [94] "Sepal width is less than 3!"
#  [95] "Sepal width is less than 3!"
#  [96] "Sepal width is greater than or equal to 3!"
#  [97] "Sepal width is less than 3!"
#  [98] "Sepal width is less than 3!"
#  [99] "Sepal width is less than 3!"
# [100] "Sepal width is less than 3!"
# [101] "Sepal width is greater than or equal to 3!"
# [102] "Sepal width is less than 3!"
# [103] "Sepal width is greater than or equal to 3!"
# [104] "Sepal width is less than 3!"
# [105] "Sepal width is greater than or equal to 3!"
# [106] "Sepal width is greater than or equal to 3!"
# [107] "Sepal width is less than 3!"
# [108] "Sepal width is less than 3!"
# [109] "Sepal width is less than 3!"
# [110] "Sepal width is greater than or equal to 3!"
# [111] "Sepal width is greater than or equal to 3!"
# [112] "Sepal width is less than 3!"
# [113] "Sepal width is greater than or equal to 3!"
# [114] "Sepal width is less than 3!"
# [115] "Sepal width is less than 3!"
# [116] "Sepal width is greater than or equal to 3!"
# [117] "Sepal width is greater than or equal to 3!"
# [118] "Sepal width is greater than or equal to 3!"
# [119] "Sepal width is less than 3!"
# [120] "Sepal width is less than 3!"
# [121] "Sepal width is greater than or equal to 3!"
# [122] "Sepal width is less than 3!"
# [123] "Sepal width is less than 3!"
# [124] "Sepal width is less than 3!"
# [125] "Sepal width is greater than or equal to 3!"
# [126] "Sepal width is greater than or equal to 3!"
# [127] "Sepal width is less than 3!"
# [128] "Sepal width is greater than or equal to 3!"
# [129] "Sepal width is less than 3!"
# [130] "Sepal width is greater than or equal to 3!"
# [131] "Sepal width is less than 3!"
# [132] "Sepal width is greater than or equal to 3!"
# [133] "Sepal width is less than 3!"
# [134] "Sepal width is less than 3!"
# [135] "Sepal width is less than 3!"
# [136] "Sepal width is greater than or equal to 3!"
# [137] "Sepal width is greater than or equal to 3!"
# [138] "Sepal width is greater than or equal to 3!"
# [139] "Sepal width is greater than or equal to 3!"
# [140] "Sepal width is greater than or equal to 3!"
# [141] "Sepal width is greater than or equal to 3!"
# [142] "Sepal width is greater than or equal to 3!"
# [143] "Sepal width is less than 3!"
# [144] "Sepal width is greater than or equal to 3!"
# [145] "Sepal width is greater than or equal to 3!"
# [146] "Sepal width is greater than or equal to 3!"
# [147] "Sepal width is less than 3!"
# [148] "Sepal width is greater than or equal to 3!"
# [149] "Sepal width is greater than or equal to 3!"
# [150] "Sepal width is greater than or equal to 3!"

# %% [markdown]
# Now test to see that all of your functions work.

# %%
stopifnot(sepal_width_group_for() == sepal_width_group_ifelse(),
         sepal_width_group_for() == sepal_width_group_apply(),
         sepal_width_group_ifelse() == sepal_width_group_apply())

# %% [markdown]
# ---
#
# # Problem 4
#
# One of the best features of the `apply` function is that user-defined functions can be used. For example, given a matrix, one could use the apply function to subtract each column mean from each value using the code:

# %%
set.seed(95064)
x <- matrix(rpois(25,10),5,5)
x
apply(x,2,function(each_column){each_column - mean(each_column)})
# Out:
#      [,1] [,2] [,3] [,4] [,5]
# [1,] 13    7   16    7   13
# [2,] 10   13    6   14    8
# [3,]  8    8   12   10   15
# [4,] 12   11    7   10   15
# [5,] 14   13   11   13   14
#      [,1] [,2] [,3] [,4] [,5]
# [1,]  1.6 -3.4  5.6 -3.8  0
# [2,] -1.4  2.6 -4.4  3.2 -5
# [3,] -3.4 -2.4  1.6 -0.8  2
# [4,]  0.6  0.6 -3.4 -0.8  2
# [5,]  2.6  2.6  0.6  2.2  1

# %% [markdown]
# Create a function that takes a matrix as an input and outputs the difference between each data point and its column minimum divided by the column range (the maximum minus the minimum) using the `apply` function.
#
# As a hint: All values in the output matrix should be between 0 and 1.

# %%
m <- matrix(rpois(25,10),5,5)
m
your_function <- function(mat=m){
    return(apply(mat,2,function(col){(col - min(col)) / (max(col) - min(col))}))
}
your_function()
# Out:
#      [,1] [,2] [,3] [,4] [,5]
# [1,]  8    7   12    7   11
# [2,] 14    8    9   18   12
# [3,] 10   10   13    7   10
# [4,] 12    5    6    8    9
# [5,] 15   14   13   14   10
#      [,1]      [,2]      [,3]      [,4]       [,5]
# [1,] 0.0000000 0.2222222 0.8571429 0.00000000 0.6666667
# [2,] 0.8571429 0.3333333 0.4285714 1.00000000 1.0000000
# [3,] 0.2857143 0.5555556 1.0000000 0.00000000 0.3333333
# [4,] 0.5714286 0.0000000 0.0000000 0.09090909 0.0000000
# [5,] 1.0000000 1.0000000 1.0000000 0.63636364 0.3333333

# %% [markdown]
# Now check that your function works correctly:

# %%
set.seed(831)
correct <- structure(c(0.538385934058501, 0, 1, 1, 0.829499385618851, 0, 
1, 0, 0.188125342183014), .Dim = c(3L, 3L))
stopifnot(round(your_function(matrix(rnorm(9),3,3)),digits=6) == round(correct,digits=6))

# %% [markdown]
# ---
#
# # Problem 5
#
# Use the `integrate` function to evaluate the following integrals:
# 1. $\int_0^1 sin(x) dx$
# 2. $\int_5^8 1 + x^3 - 4x^6 dx$
# 3. $\int_{-\pi/4}^{\pi/3} \frac{sin(x)}{\cos(x)}dx$  Note: You can use `pi` in R to get the value of $\pi$.
#
# Name your answers `one`, `two`, and `three`, respectively. Make sure your answers have the numeric class.

# %%
one <- integrate(sin, 0, 1)[[1]]
two <- integrate(function(x){1 + x^3 - 4 * x^6}, 5, 8)[[1]]
three <- integrate(function(x){sin(x)/cos(x)}, -pi/4, pi/3)[[1]]

# %%
# Checking answer one (the answer itself will not be visible to you)
if(class(one)!= "numeric") stop("Make sure your answer is numeric!")

# %%
# Checking answer two (the answer itself will not be visible to you)
if(class(two)!= "numeric") stop("Make sure your answer is numeric!")

# %%
# Checking answer three (the answer itself will not be visible to you)
if(class(three)!= "numeric") stop("Make sure your answer is numeric!")

# %% [markdown]
# ---
#
# # Problem 6
#
# Use R to find the roots of the following functions:
# 1. $f(x) = 6 - x + 5x^4$
# 2. $f(x) = \sin(x) - \cos(x)$  Note: Since this is a periodic function, just find the roots between 0 and $\pi$.
#
# Name your answers `one` and `two` respectively, and make sure they have the classes `numeric` or `complex`.

# %%
# both answers manually compared with solution from wolfram alpha
one <- polyroot(c(6,-1,0,0,5))
two <- uniroot(function(x){sin(x)-cos(x)}, c(0,pi))[[1]]

# %%
# Checking answer one (the answer itself will not be visible to you)

# %%
# Checking answer two (the answer itself will not be visible to you)

# %% [markdown]
# ---
#
# # Problem 7
#
# Use R to find:
# 1. The minimum of the function $f(x) = \frac{x}{\log{x}}$ on the domain $(1,\infty)$.
# 2. The minimum of the function $f(x,y) = x^2 + (x - \cos(x - \frac{\pi}{10}))(y - \cos(y + \frac{\pi}{12})) + y^2$
#
# Note that for both of these, the minimum value of the function is being asked for, not the values of the inputs to achieve the minimum. Once again, name your answers `one` and `two`, respectively. For the second function, use the quasi-Newton method.

# %%
one <- optimize(function(x){x/log(x)}, c(1, 100000))[[1]] #Inf throws error, so just used "large" number for upper limit
# tried increasingly large numbers for upper limit, answer hovers around ~2.7183

# %%
f <- function(x){
    x <- matrix(x, ncol=2)
    x1<-x[,1]
    x2<-x[,2]
    return(x1^2 + (x1 - cos(x1 - (pi / 10)))*(x2 - cos(x2 + (pi / 12))) + x2^2)
}

two <- optim (c(1,1), f, gr = NULL, method="BFGS") [[1]]

# %%
two
# Out:
# [1] -0.2031808  1.0551336
